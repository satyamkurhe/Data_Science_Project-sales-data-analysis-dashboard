# %% [markdown]
# # 📘 Data Science Project Sales Data Analysis
#
# This project performs detailed Exploratory Data Analysis (EDA) on a fictional sales dataset to gain business insights.
#
# ---
#
# ## 🎯 Objective
# Analyze key sales metrics:
# - Revenue by month
# - Best-selling products
# - Performance by region
# - Category contribution
#
# ---
#
# ## 📦 Step 1: Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
#
# ## 📁 Step 2: Load Dataset
# Dataset columns:
# - Order ID
# - Date
# - Product
# - Category
# - Quantity
# - Price
# - Region

# %%
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    Order ID        Date     Product     Category  Quantity  Price Region
# 0      1000  2023-07-04      Laptop  Electronics         5  24571  North
# 1      1001  2023-10-07  Headphones  Accessories         5  25356  South
# 2      1002  2023-04-13    Keyboard  Accessories         1  30186   East
# 3      1003  2023-07-23  Smartphone  Electronics         5  34770  North
# 4      1004  2023-09-25  Smartphone  Electronics         1   9073   East

# %% [markdown]
# ---
#
# ## 📊 Step 3: Monthly Sales Trend

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M')

monthly_sales = df.groupby('Month')['Price'].sum()

monthly_sales.plot(kind='bar', color='skyblue', figsize=(10,5))
plt.title(" Monthly Revenue")
plt.ylabel("Revenue")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 🏆 Step 4: Top-Selling Products

# %%
top_products = df.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head(5)

top_products.plot(kind='bar', color='green')
plt.title(" Top 5 Products by Quantity Sold")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 🌍 Step 5: Sales by Region

# %%
sns.barplot(data=region_sales_df, x="Region", y="Revenue")
plt.title("Sales by Region")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 🧾 Step 6: Category Contribution

# %%
category_sales = df.groupby('Category')['Price'].sum()

plt.pie(category_sales, labels=category_sales.index, autopct='%1.1f%%', startangle=140)
plt.title(" Category Contribution to Revenue")
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
#
# ## ✅ Conclusion
#
# Using this sales data, we:
# - Analyzed monthly trends
# - Identified top products
# - Found best performing regions
# - Visualized category-wise performance
#
# This dashboard gives a business a clear snapshot of performance and helps in decision-making.
